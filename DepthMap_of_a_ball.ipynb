# %% [markdown]
# <a href="https://colab.research.google.com/github/hilakornis/VisualPatrolBot/blob/main/DepthMap_of_a_ball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
from PIL import Image
import requests

# load pipe
pipe = pipeline(task="depth-estimation", model="depth-anything/Depth-Anything-V2-Large-hf")

# load image
# url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
# image = Image.open(requests.get(url, stream=True).raw)
image = Image.open("/content/data/ball with table.png")

# inference
depth = pipe(image)["depth"]
# Out:
# Device set to use cuda:0

# %%
import numpy as np

np.array(depth)
# Out:
# array([[  2,   2,   2, ...,  71,  68,  61],
#        [  2,   2,   2, ...,  71,  70,  69],
#        [  2,   2,   2, ...,  70,  71,  72],
#        ...,
#        [252, 252, 252, ..., 233, 233, 233],
#        [253, 253, 253, ..., 234, 234, 234],
#        [253, 254, 253, ..., 234, 235, 235]], dtype=uint8)
